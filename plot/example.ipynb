# %%
# Import required modules
import numpy as np
import matplotlib.pyplot as plt

# Meshgrid
x, y = np.meshgrid(np.linspace(-4, 4, 8), np.linspace(-4, 4, 8))

u = 3*x - 2*y
v = -x + 2*y

# Plotting Vector Field with QUIVER
plt.quiver(x, y, u, v, color='g')
plt.title('Vector Field')
plt.streamplot(x, y, u, v, density = 0.5, linewidth = 2, color='brown')

# Setting x, y boundary limits
plt.xlim(-4, 4)
plt.ylim(-4, 4)
plt.plot(0,0,'-or')

# Show plot with grid
plt.grid()
plt.show()

# %% [markdown]
# ## Example 1.2 (8 cases)

# %%
# Import required modules
import numpy as np
import matplotlib.pyplot as plt

# Meshgrid
x, y = np.meshgrid(np.linspace(-4, 4, 8), np.linspace(-4, 4, 8))

# Case 1
u = 3*x - 2*y
v = -x + 2*y
# #Case 2
# u = -1*x + 2*y
# v = x + 0*y
# #Case 3
# u = -2*x + 3*y
# v = -x + y
# #Case 4
# u = 2*x + 2*y
# v = -x - y
# #Case 5
# u = 1*x + 1*y
# v = -3*x - 3*y
# #Case 6
# u = 1*x + 2*y
# v = -2*x + 1*y
# #Case 7
# u = -1*x + 2*y
# v = -2*x - 1*y
# #Case 8
# u = y 
# v = -x


# Plotting Vector Field with QUIVER
plt.quiver(x, y, u, v, color='g')
plt.title('Vector Field')
plt.streamplot(x, y, u, v, density = 0.5, linewidth = 2, color='brown')

# Setting x, y boundary limits
plt.xlim(-4, 4)
plt.ylim(-4, 4)
plt.plot(0,0,'-or')

# Show plot with grid
plt.grid()
plt.show()
